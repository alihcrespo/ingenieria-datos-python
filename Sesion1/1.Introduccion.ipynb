# %%
print('Hola Mundo')
# Out:
# Hola Mundo

# %%
if True:
    print('Hola')
    x=40
print('Salida')
# Out:
# Hola
# Salida

# %%
lista1=['manzana','pera', 4,[9,8,'Papas']]
print(lista1)
print(lista1[3][2])
# Out:
# ['manzana', 'pera', 4, [9, 8, 'Papas']]
# Papas

# %%
print(lista1[-2])
# Out:
# 4

# %%
lista2=[1,2,3,4,5,6,7,8,9]
print(lista2[7:])
# Out:
# [8, 9]

# %%
lista2[4]=20
print(lista2)
# Out:
# [1, 2, 3, 4, 20, 6, 7, 8, 9]

# %%
lista2.append(11)
print(lista2)
# Out:
# [1, 2, 3, 4, 20, 6, 7, 8, 9, 11, 11]

# %%
lista3=[1,30,40]
lista2.extend(lista3)
lista2.remove(7)
print(lista2)
# Out:
# [1, 2, 3, 4, 20, 6, 8, 9, 20, 30, 40, 20, 30, 40, 20, 30, 40, 20, 30, 40, 0, 30, 40, 1, 30, 40, 1, 30, 40]

# %%
diccionario = {1:'Manzana', 2:'Balon', 3:5}
print(diccionario[1])
# Out:
# Manzana

# %%
diccionario1 = {'nombre':'Juan', 'telefono':'7243797'}
print(diccionario1)
diccionario1['direccion']='calle 1'
print(diccionario1)
# Out:
# {'nombre': 'Juan', 'telefono': '7243797'}
# {'nombre': 'Juan', 'telefono': '7243797', 'direccion': 'calle 1'}

# %%
var1 = 10 
if var1 < 12:
    print('True')
# Out:
# True

# %%
for item in lista2:
    if (item == 20):
        print(item*2)
# Out:
# 40
# 40
# 40
# 40
# 40

# %%
def nombre_funcion():
    print('Hola Mundo')

# %%
def di_hola(nombre):
    print('Hola ',nombre)

# %%
di_hola('Jose Luis')
# Out:
# Hola  Jose Luis
